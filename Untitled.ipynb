# %%
from canvas import Canvas
from tile import Tileset
import random

WIDTH = 2
HEIGHT = 2

ts = Tileset('tiles/')

canvas = Canvas(ts, WIDTH, HEIGHT)

while not canvas.is_finished():
    try:
        canvas = Canvas(ts, WIDTH, HEIGHT)
        
        x = random.randint(0, WIDTH-1)
        y = random.randint(0, HEIGHT-1)

        print(x, y)

        canvas.collapse_cell(x, y)

        while not canvas.is_finished():
            x, y = canvas.find_candidate()
            canvas.collapse_cell(x, y)
    
    except Exception as e:
        print(e)
# Out:
# 1 0
# {'tile': '0.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}
# Cell(xcoord=1, ycoord=0, collapsed=False, tile='0.png', n_rotations=0, options=[{'tile': '0.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=3, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=3, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='l', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=2, hash_val='00000 ...
# Cell collapsed (1, 0) with 0.png rotation stage: 0
# Candidate found (0, 0)
# {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}
# Cell(xcoord=0, ycoord=0, collapsed=False, tile='1.png', n_rotations=2, options=[{'tile': '0.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '3.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '3.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '3.png', 'joint': Joint(position='r', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '4.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '4.png', 'joint': Joint(position='r', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '5.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '5.png', 'joint': Joint(position='r', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}], north=None, east=[1, 0], south=[0, 1], west=None)
# Cell collapsed (0, 0) with 1.png rotation stage: 2
# Candidate found (0, 1)
# {'tile': '4.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}
# Cell(xcoord=0, ycoord=1, collapsed=False, tile='4.png', n_rotations=0, options=[{'tile': '0.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=3, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=3, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='l', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=2, hash_val='00000 ...
# Cell collapsed (0, 1) with 4.png rotation stage: 0
# Candidate found (1, 1)
# {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}
# Cell(xcoord=1, ycoord=1, collapsed=False, tile='2.png', n_rotations=0, options=[{'tile': '0.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '0.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='u', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='r', rotation_stage=3, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='d', rotation_stage=3, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '1.png', 'joint': Joint(position='l', rotation_stage=3, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=0, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='l', rotation_stage=0, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=1, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='l', rotation_stage=1, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='u', rotation_stage=2, hash_val='000000000000000000ffffffffffff000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='r', rotation_stage=2, hash_val='000000000000000000000000000000000000000000000000')}, {'tile': '2.png', 'joint': Joint(position='d', rotation_stage=2, hash_val='00000 ...
# Cell collapsed (1, 1) with 2.png rotation stage: 0

# %%
canvas.render()
